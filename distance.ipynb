# %%
pip install googlemaps
# Out:
# Requirement already satisfied: googlemaps in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (from googlemaps) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\merfc\Documents\GitHub\.venv\Lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pakiet i API do dystansu 
import googlemaps
gmaps = googlemaps.Client(key="AIzaSyDNvRhZKdSYX5O1btoSVn3pcZDdDboKhL4")

# %%
#funkcja to liczenia dystansu
def dystans1(poczatek, koniec): 
    result = gmaps.distance_matrix(poczatek, koniec, mode="bicycling")
    #return bool(result['destination_addresses']!="" and result['origin_addresses']!="")
    #return result
    return result["rows"][0]["elements"][0]["status"][0]

# %%
a = dystans1(origin,destination)
print(a)
# Out:
# Z

# %%
#funkcja to liczenia dystansu
def dystans(poczatek, koniec): 
    result = gmaps.distance_matrix(poczatek, koniec, mode="bicycling")
    if result["rows"][0]["elements"][0]["status"][0] == "O":
        distance = result["rows"][0]["elements"][0]["distance"]["text"]
        return distance
    else:
        return "Brak"

# %%
origin = "Blue City"
destination = "Chrościckiego – al. 4 Czerwca 1989 r."

# %%
dystans("aha", "katowice")
# Out:
# 'Brak'

# %%
dystans(origin,destination)
# Out:
# 'Brak'
