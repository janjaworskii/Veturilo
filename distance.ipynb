# %%
pip install googlemaps
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: googlemaps in /home/215f8729-c2e2-41c8-89da-7303ecff642d/.local/lib/python3.12/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from googlemaps) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pakiet i API do dystansu 
import googlemaps
gmaps = googlemaps.Client(key="AIzaSyDNvRhZKdSYX5O1btoSVn3pcZDdDboKhL4")

# %%
#funkcja to liczenia dystansu
def dystans(poczatek, koniec): 
    result = gmaps.distance_matrix(poczatek, koniec, mode="bicycling")
    distance = result["rows"][0]["elements"][0]["distance"]["text"]
    return distance

# %%
origin = "Stefana Banacha - UW Warszawa"
destination = "Łódź"

# %%
dystans(origin,destination)
# Out:
# '136 km'
